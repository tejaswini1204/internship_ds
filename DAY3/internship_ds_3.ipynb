# %%
import matplotlib.pyplot as plt
x=[0,1,2,3,4,5]
y=[0,1,4,9,16,25]
plt.plot(x,y)
plt.show()

# %%
plt.plot([1,2,3,4])
plt.ylabel('SOME NUMBERS')
plt.show()

# %%
x1=[1,2,3]
y1=[2,4,1]
plt.plot(x1,y1,label="line1")
x2=[1,2,3]
y2=[4,1,3]
plt.plot(x2,y2,label="line2")
plt.xlabel('X-AXIS')
plt.ylabel('Y-AXIS')
plt.title('TWO LINES ON SAME GRAPH!!')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt 
x = [1,2,3,4,5,6] 
y = [2,4,1,5,2,6]   
plt.plot(x, y, color='green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)
plt.ylim(1,8) 
plt.xlim(1,8) 
plt.xlabel('x - axis')
plt.ylabel('y - axis') 
plt.title('Some cool customizations!') 
plt.show()

# %%
values=[5,6,3,7,2]
names=["A","B","C","D","E"]
plt.bar(names,values,color="cyan")
plt.show()

# %%
import numpy as np
values=np.array([5,6,3,7,2])
names=np.array(["A","B","C","D","E"])
c=(['red','blue','purple','yellow','orange'])
plt.barh(names,values,color=c)
plt.show()

# %%
ages=[2,5,70,40,30,45,50,45,43,40,44,60,7,13,57,18,90,77,32,21,40]
range=(0,100)
bins=10
plt.hist(ages,bins,range,color='purple',histtype='bar',edgecolor='black')
plt.xlabel('AGE')
plt.ylabel('NO OF PEOPLE')
plt.title('MY HISTOGRAM')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [2,1,6,4,2,4,8,9,4,2,4,10,6,4,5,7,7,3,2,7,5,3,5,9,2,1]
plt.hist(x, bins = 10, color='pink', alpha=0.5)
plt.show()

# %%
x=[0,1,2,3,4,5]
y=[0,1,4,9,16,25]
plt.scatter(x,y,s=30,color="purple")
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3,4,5])
y=np.array([0,1,4,9,16,25])
c=np.array(['red','blue','yellow','black','grey','green'])
plt.scatter(x,y,s=30,color=c)
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3,4,5])
y=np.array([0,1,4,9,16,25])
c=np.array(['red','blue','yellow','black','grey','green'])
plt.scatter(x,y,s=30,color=c,marker="^")
plt.show()

# %%
x=['SEM 1','SEM 2','SEM 3','SEM 4']
sizes = [15, 30, 25, 30]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0, 0.1)
plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=x, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('SEMESTER')
plt.show()

# %%
activities=['EAT','SLEEP','WORK','PLAY']
slices=[3,7,8,6]
colors=['r','y','g','b']
plt.pie(slices,labels=activities,colors=colors,startangle=90,shadow=True,radius=1.2,explode=(0.1,0.1,0.1,0.1),autopct='%1.1f%%')
plt.legend()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x = np.arange(0, 2*(np.pi), 0.1) 
y = np.sin(x) 
plt.plot(x, y) 
plt.show()
